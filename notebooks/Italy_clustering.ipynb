# %%
from sklearn.cluster import AgglomerativeClustering, KMeans
import numpy as np
import seaborn as sns
import pandas as pd
import random

from diurnal_misinformation.config import ItalyConfig
from diurnal_misinformation.enums import Columns, Clusters
from diurnal_misinformation.cluster_utils import ClusterRoutine, cluster_center_df
from diurnal_misinformation.path_utils import get_cluster_col_path

# %%
random_seed = 12
np.random.seed(random_seed)
random.seed(random_seed)

# %%
config = ItalyConfig()
methods = {
    'kmeans': KMeans(random_state=random_seed),
    'hierarchical': AgglomerativeClustering(linkage='ward', metric='euclidean'),
}
routine = ClusterRoutine(config, methods=methods, cutoff_post_nr=240)

# %% [markdown]
# # Pseudo-Chronotypes
#
# We assume circadian variation on two levels: Variation in ratios of machinated content and variation in access to Twitter/capacity to tweet. We need to disentangle both effects.
#
# ## Aggregation
# Ideally, we would model the time series continuously per each user over the time period that we have available, and then to separate seasonality/cyclical patterns, trend, and noise. This would allow us to isolate seasonality. However (1) that's resource-intense, (2) our data is so sparse it may not make much sense for all but the most active users and (3) few Twitter users are persistant, in that the inter-individual similarity in between subsequent days is small.

# %% [markdown]
# ## Smoothing
#
# We're trying to model one "standard" day for each user. Most Twitter users, however, don't necessarily post enough to fill all 15-minute bins with some value even if they are on Twitter, so we have to interpolate (this is not a problem for users who post a lot, as we've seen above).
#
# We only have 24\*4=96 datapoints, meaning that we should not assume a distribution (we can't rely on the rule of large numbers either). So parametric fitting can lead to fitting a smooth curve that misrepresents the data. This leaves non-parametric smoothing methods like LOWESS or moving averages.
#
# LOWESS/LOESS require fairly large, densely sampled data sets since they fit a model over local data structures, plus is sensitive to outliers. We just have one datapoint every 15 minutes. So moving average seems the better choice. Closed domain is sufficient for our use case, so we don't need EWA for responsiveness. Weighted moving average seemed a reasonable compromise between smoothing and data point consideration.
#
# I chose the window size as 90 minutes because a) it gave good results and b) is suits the human ultradian rhythm.
#
# Note that this is just for clustering: We'll apply Fourier smoothing afterwards on the aggregated curves.

# %%
routine.smooth_user_activity(padding=3, std=3)

# %% [markdown]
# # Clustering
#
# Let's compare hierarchical and kmeans clustering. We want at least 3 clusters for a sensible analysis. We can compare element-wise per index to find the more promising candidate.
#
# Generally, we want to measure when people are awake, so it's important to collect all the Tweets.

# %%
cluster_result_all = routine.routine_by(routine.smoothed_user_activity, 'all')
# Out:
# <style type="text/css">
# #T_f8e02_row0_col7, #T_f8e02_row1_col7, #T_f8e02_row2_col10, #T_f8e02_row3_col0, #T_f8e02_row4_col3, #T_f8e02_row5_col7 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f8e02">
#   <thead>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th id="T_f8e02_level0_col0" class="col_heading level0 col0" colspan="7">hierarchical</th>
#       <th id="T_f8e02_level0_col7" class="col_heading level0 col7" colspan="7">kmeans</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_f8e02_level1_col0" class="col_heading level1 col0" >3</th>
#       <th id="T_f8e02_level1_col1" class="col_heading level1 col1" >4</th>
#       <th id="T_f8e02_level1_col2" class="col_heading level1 col2" >5</th>
#       <th id="T_f8e02_level1_col3" class="col_heading level1 col3" >6</th>
#       <th id="T_f8e02_level1_col4" class="col_heading level1 col4" >7</th>
#       <th id="T_f8e02_level1_col5" class="col_heading level1 col5" >8</th>
#       <th id="T_f8e02_level1_col6" class="col_heading level1 col6" >9</th>
#       <th id="T_f8e02_level1_col7" class="col_heading level1 col7" >3</th>
#       <th id="T_f8e02_level1_col8" class="col_heading level1 col8" >4</th>
#       <th id="T_f8e02_level1_col9" class="col_heading level1 col9" >5</th>
#       <th id="T_f8e02_level1_col10" class="col_heading level1 col10" >6</th>
#       <th id="T_f8e02_level1_col11" class="col_heading level1 col11" >7</th>
#       <th id="T_f8e02_level1_col12" class="col_heading level1 col12" >8</th>
#       <th id="T_f8e02_level1_col13" class="col_heading level1 col13" >9</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >indicator</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8e02_level0_row0" class="row_heading level0 row0" >calinski</th>
#       <td id="T_f8e02_row0_col0" class="data row0 col0" >1340.370305</td>
#       <td id="T_f8e02_row0_col1" class="data row0 col1" >1219.154722</td>
#       <td id="T_f8e02_row0_col2" class="data row0 col2" >1167.719417</td>
#       <td id="T_f8e02_row0_col3" class="data row0 col3" >1149.252520</td>
#       <td id="T_f8e02_row0_col4" class="data row0 col4" >1047.618761</td>
#       <td id="T_f8e02_row0_col5" class="data row0 col5" >974.827020</td>
#       <td id="T_f8e02_row0_col6" class="data row0 col6" >920.815729</td>
#       <td id="T_f8e02_row0_col7" class="data row0 col7" >1765.441883</td>
#       <td id="T_f8e02_row0_col8" class="data row0 col8" >1484.919230</td>
#       <td id="T_f8e02_row0_col9" class="data row0 col9" >1455.289882</td>
#       <td id="T_f8e02_row0_col10" class="data row0 col10" >1435.901438</td>
#       <td id="T_f8e02_row0_col11" class="data row0 col11" >1322.483438</td>
#       <td id="T_f8e02_row0_col12" class="data row0 col12" >1246.124278</td>
#       <td id="T_f8e02_row0_col13" class="data row0 col13" >1155.624791</td>
#     </tr>
#     <tr>
#       <th id="T_f8e02_level0_row1" class="row_heading level0 row1" >cop</th>
#       <td id="T_f8e02_row1_col0" class="data row1 col0" >0.119372</td>
#       <td id="T_f8e02_row1_col1" class="data row1 col1" >0.120849</td>
#       <td id="T_f8e02_row1_col2" class="data row1 col2" >0.122184</td>
#       <td id="T_f8e02_row1_col3" class="data row1 col3" >0.124390</td>
#       <td id="T_f8e02_row1_col4" class="data row1 col4" >0.152623</td>
#       <td id="T_f8e02_row1_col5" class="data row1 col5" >0.163551</td>
#       <td id="T_f8e02_row1_col6" class="data row1 col6" >0.164514</td>
#       <td id="T_f8e02_row1_col7" class="data row1 col7" >0.116760</td>
#       <td id="T_f8e02_row1_col8" class="data row1 col8" >0.122737</td>
#       <td id="T_f8e02_row1_col9" class="data row1 col9" >0.121715</td>
#       <td id="T_f8e02_row1_col10" class="data row1 col10" >0.121914</td>
#       <td id="T_f8e02_row1_col11" class="data row1 col11" >0.119809</td>
#       <td id="T_f8e02_row1_col12" class="data row1 col12" >0.120023</td>
#       <td id="T_f8e02_row1_col13" class="data row1 col13" >0.118480</td>
#     </tr>
#     <tr>
#       <th id="T_f8e02_level0_row2" class="row_heading level0 row2" >davies</th>
#       <td id="T_f8e02_row2_col0" class="data row2 col0" >2.235584</td>
#       <td id="T_f8e02_row2_col1" class="data row2 col1" >2.024005</td>
#       <td id="T_f8e02_row2_col2" class="data row2 col2" >1.927595</td>
#       <td id="T_f8e02_row2_col3" class="data row2 col3" >1.730220</td>
# Clustered into 3 clusters using kmeans

# %%
g = sns.lineplot(
    pd.DataFrame(cluster_result_all.cluster_centers, columns=routine.smoothed_user_activity.columns).rename(index=cluster_result_all.num_to_name).T, 
    palette=Clusters.palette())
g.set_xlabel('time')
# Out:
# Text(0.5, 0, 'time')

# %% [markdown]
# ## Cluster stats

# %%
stats_dist_df_style = routine.get_cluster_stats_distance_table_style(cluster_result_all, save=True)
stats_dist_df_style
# Out:
# <style type="text/css">
# #T_f9357_row0_col3, #T_f9357_row1_col4, #T_f9357_row2_col5, #T_f9357_row3_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f9357">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9357_level0_col0" class="col_heading level0 col0" >number of users</th>
#       <th id="T_f9357_level0_col1" class="col_heading level0 col1" >number of posts</th>
#       <th id="T_f9357_level0_col2" class="col_heading level0 col2" >posts per user</th>
#       <th id="T_f9357_level0_col3" class="col_heading level0 col3" >infrequent type</th>
#       <th id="T_f9357_level0_col4" class="col_heading level0 col4" >morning type</th>
#       <th id="T_f9357_level0_col5" class="col_heading level0 col5" >intermediate type</th>
#       <th id="T_f9357_level0_col6" class="col_heading level0 col6" >evening type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9357_level0_row0" class="row_heading level0 row0" >infrequent type</th>
#       <td id="T_f9357_row0_col0" class="data row0 col0" >860,228</td>
#       <td id="T_f9357_row0_col1" class="data row0 col1" >7,858,209</td>
#       <td id="T_f9357_row0_col2" class="data row0 col2" >9.14</td>
#       <td id="T_f9357_row0_col3" class="data row0 col3" >0.408</td>
#       <td id="T_f9357_row0_col4" class="data row0 col4" >-</td>
#       <td id="T_f9357_row0_col5" class="data row0 col5" >-</td>
#       <td id="T_f9357_row0_col6" class="data row0 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_f9357_level0_row1" class="row_heading level0 row1" >morning type</th>
#       <td id="T_f9357_row1_col0" class="data row1 col0" >3,155</td>
#       <td id="T_f9357_row1_col1" class="data row1 col1" >2,815,887</td>
#       <td id="T_f9357_row1_col2" class="data row1 col2" >892.52</td>
#       <td id="T_f9357_row1_col3" class="data row1 col3" >0.058</td>
#       <td id="T_f9357_row1_col4" class="data row1 col4" >0.131</td>
#       <td id="T_f9357_row1_col5" class="data row1 col5" >-</td>
#       <td id="T_f9357_row1_col6" class="data row1 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_f9357_level0_row2" class="row_heading level0 row2" >intermediate type</th>
#       <td id="T_f9357_row2_col0" class="data row2 col0" >5,461</td>
#       <td id="T_f9357_row2_col1" class="data row2 col1" >5,199,655</td>
#       <td id="T_f9357_row2_col2" class="data row2 col2" >952.14</td>
#       <td id="T_f9357_row2_col3" class="data row2 col3" >0.044</td>
#       <td id="T_f9357_row2_col4" class="data row2 col4" >0.061</td>
#       <td id="T_f9357_row2_col5" class="data row2 col5" >0.111</td>
#       <td id="T_f9357_row2_col6" class="data row2 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_f9357_level0_row3" class="row_heading level0 row3" >evening type</th>
#       <td id="T_f9357_row3_col0" class="data row3 col0" >2,654</td>
#       <td id="T_f9357_row3_col1" class="data row3 col1" >2,338,475</td>
#       <td id="T_f9357_row3_col2" class="data row3 col2" >881.11</td>
#       <td id="T_f9357_row3_col3" class="data row3 col3" >0.035</td>
#       <td id="T_f9357_row3_col4" class="data row3 col4" >0.090</td>
#       <td id="T_f9357_row3_col5" class="data row3 col5" >0.073</td>
#       <td id="T_f9357_row3_col6" class="data row3 col6" >0.158</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Unverified
# We should validate that the clusters found when considering all users are representative of Tweets by unverified users only.

# %%
unverified_users = routine.processor.data.xs(False, level=Columns.VERIFIED.value).index.unique(level=Columns.USERHASH.value)
cluster_result_unverified = routine.routine_by(routine.smoothed_user_activity.loc[unverified_users], 'unverified')
# Out:
# <style type="text/css">
# #T_46ffa_row0_col7, #T_46ffa_row1_col7, #T_46ffa_row2_col10, #T_46ffa_row3_col0, #T_46ffa_row4_col2, #T_46ffa_row5_col7 {
#   font-weight: bold;
# }
# </style>
# <table id="T_46ffa">
#   <thead>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th id="T_46ffa_level0_col0" class="col_heading level0 col0" colspan="7">hierarchical</th>
#       <th id="T_46ffa_level0_col7" class="col_heading level0 col7" colspan="7">kmeans</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_46ffa_level1_col0" class="col_heading level1 col0" >3</th>
#       <th id="T_46ffa_level1_col1" class="col_heading level1 col1" >4</th>
#       <th id="T_46ffa_level1_col2" class="col_heading level1 col2" >5</th>
#       <th id="T_46ffa_level1_col3" class="col_heading level1 col3" >6</th>
#       <th id="T_46ffa_level1_col4" class="col_heading level1 col4" >7</th>
#       <th id="T_46ffa_level1_col5" class="col_heading level1 col5" >8</th>
#       <th id="T_46ffa_level1_col6" class="col_heading level1 col6" >9</th>
#       <th id="T_46ffa_level1_col7" class="col_heading level1 col7" >3</th>
#       <th id="T_46ffa_level1_col8" class="col_heading level1 col8" >4</th>
#       <th id="T_46ffa_level1_col9" class="col_heading level1 col9" >5</th>
#       <th id="T_46ffa_level1_col10" class="col_heading level1 col10" >6</th>
#       <th id="T_46ffa_level1_col11" class="col_heading level1 col11" >7</th>
#       <th id="T_46ffa_level1_col12" class="col_heading level1 col12" >8</th>
#       <th id="T_46ffa_level1_col13" class="col_heading level1 col13" >9</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >indicator</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46ffa_level0_row0" class="row_heading level0 row0" >calinski</th>
#       <td id="T_46ffa_row0_col0" class="data row0 col0" >1280.064853</td>
#       <td id="T_46ffa_row0_col1" class="data row0 col1" >1206.612199</td>
#       <td id="T_46ffa_row0_col2" class="data row0 col2" >1141.392983</td>
#       <td id="T_46ffa_row0_col3" class="data row0 col3" >1110.048591</td>
#       <td id="T_46ffa_row0_col4" class="data row0 col4" >1014.514084</td>
#       <td id="T_46ffa_row0_col5" class="data row0 col5" >950.607172</td>
#       <td id="T_46ffa_row0_col6" class="data row0 col6" >891.119585</td>
#       <td id="T_46ffa_row0_col7" class="data row0 col7" >1735.286232</td>
#       <td id="T_46ffa_row0_col8" class="data row0 col8" >1463.286299</td>
#       <td id="T_46ffa_row0_col9" class="data row0 col9" >1420.496994</td>
#       <td id="T_46ffa_row0_col10" class="data row0 col10" >1404.146040</td>
#       <td id="T_46ffa_row0_col11" class="data row0 col11" >1291.757231</td>
#       <td id="T_46ffa_row0_col12" class="data row0 col12" >1216.623692</td>
#       <td id="T_46ffa_row0_col13" class="data row0 col13" >1152.615673</td>
#     </tr>
#     <tr>
#       <th id="T_46ffa_level0_row1" class="row_heading level0 row1" >cop</th>
#       <td id="T_46ffa_row1_col0" class="data row1 col0" >0.122740</td>
#       <td id="T_46ffa_row1_col1" class="data row1 col1" >0.121308</td>
#       <td id="T_46ffa_row1_col2" class="data row1 col2" >0.123535</td>
#       <td id="T_46ffa_row1_col3" class="data row1 col3" >0.124629</td>
#       <td id="T_46ffa_row1_col4" class="data row1 col4" >0.125411</td>
#       <td id="T_46ffa_row4_col2" class="data row4 col2" >0.032073</td>
#       <td id="T_46ffa_row4_col3" class="data row4 col3" >0.032073</td>
#       <td id="T_46ffa_row4_col4" class="data row4 col4" >0.032073</td>
#       <td id="T_46ffa_row4_col5" class="data row4 col5" >0.032073</td>
#       <td id="T_46ffa_row4_col6" class="data row4 col6" >0.032073</td>
#       <td id="T_46ffa_row4_col7" class="data row4 col7" >0.027367</td>
#       <td id="T_46ffa_row4_col8" class="data row4 col8" >0.014590</td>
#       <td id="T_46ffa_row4_col9" class="data row4 col9" >0.007584</td>
#       <td id="T_46ffa_row4_col10" class="data row4 col10" >0.014590</td>
#       <td id="T_46ffa_row4_col11" class="data row4 col11" >0.014590</td>
#       <td id="T_46ffa_row4_col12" class="data row4 col12" >0.026863</td>
#       <td id="T_46ffa_row4_col13" class="data row4 col13" >0.007172</td>
#     </tr>
#     <tr>
#       <th id="T_46ffa_level0_row5" class="row_heading level0 row5" >silhouette</th>
#       <td id="T_46ffa_row5_col0" class="data row5 col0" >0.096561</td>
# Clustered into 3 clusters using kmeans

# %%
sns.lineplot(
    data=pd.concat([
        cluster_center_df(cluster_result_all),
        cluster_center_df(cluster_result_unverified),
    ], keys=['all', 'unverified'], names=['type']).stack().reset_index(name='activity'), 
    x=Columns.MIN_BINS15.value, y='activity', palette=Clusters.palette(), hue='cluster', style='type')
# Out:
# <Axes: xlabel='min_bins15', ylabel='activity'>

# %% [markdown]
# ## Cluster Stats

# %%
routine.get_cluster_stats_distance_table_style(cluster_result_unverified, save=True)
# Out:
# <style type="text/css">
# #T_18618_row0_col3, #T_18618_row1_col4, #T_18618_row2_col5, #T_18618_row3_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_18618">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18618_level0_col0" class="col_heading level0 col0" >number of users</th>
#       <th id="T_18618_level0_col1" class="col_heading level0 col1" >number of posts</th>
#       <th id="T_18618_level0_col2" class="col_heading level0 col2" >posts per user</th>
#       <th id="T_18618_level0_col3" class="col_heading level0 col3" >infrequent type</th>
#       <th id="T_18618_level0_col4" class="col_heading level0 col4" >morning type</th>
#       <th id="T_18618_level0_col5" class="col_heading level0 col5" >intermediate type</th>
#       <th id="T_18618_level0_col6" class="col_heading level0 col6" >evening type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18618_level0_row0" class="row_heading level0 row0" >infrequent type</th>
#       <td id="T_18618_row0_col0" class="data row0 col0" >858,188</td>
#       <td id="T_18618_row0_col1" class="data row0 col1" >7,801,792</td>
#       <td id="T_18618_row0_col2" class="data row0 col2" >9.09</td>
#       <td id="T_18618_row0_col3" class="data row0 col3" >0.408</td>
#       <td id="T_18618_row0_col4" class="data row0 col4" >-</td>
#       <td id="T_18618_row0_col5" class="data row0 col5" >-</td>
#       <td id="T_18618_row0_col6" class="data row0 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_18618_level0_row1" class="row_heading level0 row1" >morning type</th>
#       <td id="T_18618_row1_col0" class="data row1 col0" >3,157</td>
#       <td id="T_18618_row1_col1" class="data row1 col1" >2,802,925</td>
#       <td id="T_18618_row1_col2" class="data row1 col2" >887.84</td>
#       <td id="T_18618_row1_col3" class="data row1 col3" >0.058</td>
#       <td id="T_18618_row1_col4" class="data row1 col4" >0.132</td>
#       <td id="T_18618_row1_col5" class="data row1 col5" >-</td>
#       <td id="T_18618_row1_col6" class="data row1 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_18618_level0_row2" class="row_heading level0 row2" >intermediate type</th>
#       <td id="T_18618_row2_col0" class="data row2 col0" >5,397</td>
#       <td id="T_18618_row2_col1" class="data row2 col1" >5,105,142</td>
#       <td id="T_18618_row2_col2" class="data row2 col2" >945.92</td>
#       <td id="T_18618_row2_col3" class="data row2 col3" >0.043</td>
#       <td id="T_18618_row2_col4" class="data row2 col4" >0.061</td>
#       <td id="T_18618_row2_col5" class="data row2 col5" >0.112</td>
#       <td id="T_18618_row2_col6" class="data row2 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_18618_level0_row3" class="row_heading level0 row3" >evening type</th>
#       <td id="T_18618_row3_col0" class="data row3 col0" >2,516</td>
#       <td id="T_18618_row3_col1" class="data row3 col1" >2,182,114</td>
#       <td id="T_18618_row3_col2" class="data row3 col2" >867.29</td>
#       <td id="T_18618_row3_col3" class="data row3 col3" >0.036</td>
#       <td id="T_18618_row3_col4" class="data row3 col4" >0.090</td>
#       <td id="T_18618_row3_col5" class="data row3 col5" >0.073</td>
#       <td id="T_18618_row3_col6" class="data row3 col6" >0.157</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Verified

# %%
cluster_result_verified = routine.routine_by(routine.smoothed_user_activity.loc[routine.smoothed_user_activity.index.difference(unverified_users)], 'verified')
# Out:
# <style type="text/css">
# #T_38995_row0_col8, #T_38995_row1_col0, #T_38995_row2_col7, #T_38995_row3_col7, #T_38995_row4_col7, #T_38995_row5_col7 {
#   font-weight: bold;
# }
# </style>
# <table id="T_38995">
#   <thead>
#     <tr>
#       <th class="index_name level0" >method</th>
#       <th id="T_38995_level0_col0" class="col_heading level0 col0" colspan="7">hierarchical</th>
#       <th id="T_38995_level0_col7" class="col_heading level0 col7" colspan="7">kmeans</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_38995_level1_col0" class="col_heading level1 col0" >3</th>
#       <th id="T_38995_level1_col1" class="col_heading level1 col1" >4</th>
#       <th id="T_38995_level1_col2" class="col_heading level1 col2" >5</th>
#       <th id="T_38995_level1_col3" class="col_heading level1 col3" >6</th>
#       <th id="T_38995_level1_col4" class="col_heading level1 col4" >7</th>
#       <th id="T_38995_level1_col5" class="col_heading level1 col5" >8</th>
#       <th id="T_38995_level1_col6" class="col_heading level1 col6" >9</th>
#       <th id="T_38995_level1_col7" class="col_heading level1 col7" >3</th>
#       <th id="T_38995_level1_col8" class="col_heading level1 col8" >4</th>
#       <th id="T_38995_level1_col9" class="col_heading level1 col9" >5</th>
#       <th id="T_38995_level1_col10" class="col_heading level1 col10" >6</th>
#       <th id="T_38995_level1_col11" class="col_heading level1 col11" >7</th>
#       <th id="T_38995_level1_col12" class="col_heading level1 col12" >8</th>
#       <th id="T_38995_level1_col13" class="col_heading level1 col13" >9</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >indicator</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38995_level0_row0" class="row_heading level0 row0" >calinski</th>
#       <td id="T_38995_row0_col0" class="data row0 col0" >36.350441</td>
#       <td id="T_38995_row0_col1" class="data row0 col1" >32.578069</td>
#       <td id="T_38995_row0_col2" class="data row0 col2" >31.562748</td>
#       <td id="T_38995_row0_col3" class="data row0 col3" >30.643469</td>
#       <td id="T_38995_row0_col4" class="data row0 col4" >29.986718</td>
#       <td id="T_38995_row0_col5" class="data row0 col5" >29.771655</td>
#       <td id="T_38995_row0_col6" class="data row0 col6" >29.699959</td>
#       <td id="T_38995_row0_col7" class="data row0 col7" >26.176787</td>
#       <td id="T_38995_row0_col8" class="data row0 col8" >36.833066</td>
#       <td id="T_38995_row3_col9" class="data row3 col9" >0.972740</td>
#       <td id="T_38995_row3_col10" class="data row3 col10" >0.915760</td>
#       <td id="T_38995_row3_col11" class="data row3 col11" >0.853755</td>
#       <td id="T_38995_row3_col12" class="data row3 col12" >0.792010</td>
#       <td id="T_38995_row3_col13" class="data row3 col13" >0.738594</td>
#     </tr>
#     <tr>
#       <th id="T_38995_level0_row4" class="row_heading level0 row4" >dunn</th>
#       <td id="T_38995_row4_col0" class="data row4 col0" >0.076626</td>
#       <td id="T_38995_row4_col1" class="data row4 col1" >0.076626</td>
#       <td id="T_38995_row4_col2" class="data row4 col2" >0.094953</td>
#       <td id="T_38995_row4_col3" class="data row4 col3" >0.090849</td>
#       <td id="T_38995_row4_col4" class="data row4 col4" >0.099139</td>
#       <td id="T_38995_row4_col5" class="data row4 col5" >0.099139</td>
#       <td id="T_38995_row4_col6" class="data row4 col6" >0.113009</td>
#       <td id="T_38995_row4_col7" class="data row4 col7" >0.136535</td>
#       <td id="T_38995_row4_col8" class="data row4 col8" >0.090043</td>
#       <td id="T_38995_row4_col9" class="data row4 col9" >0.054188</td>
#       <td id="T_38995_row4_col10" class="data row4 col10" >0.067792</td>
#       <td id="T_38995_row4_col11" class="data row4 col11" >0.078892</td>
#       <td id="T_38995_row4_col12" class="data row4 col12" >0.074319</td>
#       <td id="T_38995_row4_col13" class="data row4 col13" >0.074319</td>
#     </tr>
#     <tr>
#       <th id="T_38995_level0_row5" class="row_heading level0 row5" >silhouette</th>
#       <td id="T_38995_row5_col0" class="data row5 col0" >0.288242</td>
#       <td id="T_38995_row5_col1" class="data ro
# Clustered into 3 clusters using kmeans

# %% [markdown]
# ## Stats

# %%
routine.get_cluster_stats_distance_table_style(cluster_result_verified, save=False)
# Out:
# <style type="text/css">
# #T_7825e_row0_col3, #T_7825e_row1_col4, #T_7825e_row2_col5, #T_7825e_row3_col6 {
#   font-weight: bold;
# }
# </style>
# <table id="T_7825e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7825e_level0_col0" class="col_heading level0 col0" >number of users</th>
#       <th id="T_7825e_level0_col1" class="col_heading level0 col1" >number of posts</th>
#       <th id="T_7825e_level0_col2" class="col_heading level0 col2" >posts per user</th>
#       <th id="T_7825e_level0_col3" class="col_heading level0 col3" >infrequent type</th>
#       <th id="T_7825e_level0_col4" class="col_heading level0 col4" >morning type</th>
#       <th id="T_7825e_level0_col5" class="col_heading level0 col5" >intermediate type</th>
#       <th id="T_7825e_level0_col6" class="col_heading level0 col6" >evening type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7825e_level0_row0" class="row_heading level0 row0" >infrequent type</th>
#       <td id="T_7825e_row0_col0" class="data row0 col0" >2,040</td>
#       <td id="T_7825e_row0_col1" class="data row0 col1" >56,417</td>
#       <td id="T_7825e_row0_col2" class="data row0 col2" >27.66</td>
#       <td id="T_7825e_row0_col3" class="data row0 col3" >0.422</td>
#       <td id="T_7825e_row0_col4" class="data row0 col4" >-</td>
#       <td id="T_7825e_row0_col5" class="data row0 col5" >-</td>
#       <td id="T_7825e_row0_col6" class="data row0 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_7825e_level0_row1" class="row_heading level0 row1" >morning type</th>
#       <td id="T_7825e_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_7825e_row1_col1" class="data row1 col1" >16,882</td>
#       <td id="T_7825e_row1_col2" class="data row1 col2" >1,298.62</td>
#       <td id="T_7825e_row1_col3" class="data row1 col3" >0.147</td>
#       <td id="T_7825e_row1_col4" class="data row1 col4" >0.059</td>
#       <td id="T_7825e_row1_col5" class="data row1 col5" >-</td>
#       <td id="T_7825e_row1_col6" class="data row1 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_7825e_level0_row2" class="row_heading level0 row2" >intermediate type</th>
#       <td id="T_7825e_row2_col0" class="data row2 col0" >186</td>
#       <td id="T_7825e_row2_col1" class="data row2 col1" >246,511</td>
#       <td id="T_7825e_row2_col2" class="data row2 col2" >1,325.33</td>
#       <td id="T_7825e_row2_col3" class="data row2 col3" >0.017</td>
#       <td id="T_7825e_row2_col4" class="data row2 col4" >0.143</td>
#       <td id="T_7825e_row2_col5" class="data row2 col5" >0.057</td>
#       <td id="T_7825e_row2_col6" class="data row2 col6" >-</td>
#     </tr>
#     <tr>
#       <th id="T_7825e_level0_row3" class="row_heading level0 row3" >evening type</th>
#       <td id="T_7825e_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_7825e_row3_col1" class="data row3 col1" >443</td>
#       <td id="T_7825e_row3_col2" class="data row3 col2" >443.00</td>
#       <td id="T_7825e_row3_col3" class="data row3 col3" >0.318</td>
#       <td id="T_7825e_row3_col4" class="data row3 col4" >0.368</td>
#       <td id="T_7825e_row3_col5" class="data row3 col5" >0.322</td>
#       <td id="T_7825e_row3_col6" class="data row3 col6" >0.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There are only 200 verified users with >= 240 posts in our data set, and only one evening type

# %% [markdown]
# # Comparison

# %% [markdown]
# Curve features of all, unverified and verified:

# %%
results = [cluster_result_all, cluster_result_unverified, cluster_result_verified]
merged_centers=pd.concat(list(map(lambda r: cluster_center_df(r), results)), keys=list(map(lambda r: r.label, results)), names=['type'], axis=0)
cluster_cols = pd.concat(list(map(lambda r: r.clustercol.map(r.num_to_name), results)), keys=list(map(lambda r: r.label, results)), axis=1)

# %%
cluster_cols.loc[(cluster_cols['all'] != cluster_cols['verified']) & ~cluster_cols['verified'].isna(), ['all', 'verified']].value_counts().unstack(fill_value=0)
# Out:
# verified           evening type  intermediate type
# all
# evening type                  0                 27
# intermediate type             1                  0
# morning type                  0                 50

# %%
cluster_cols.loc[(cluster_cols['all'] != cluster_cols['unverified']) & ~cluster_cols['unverified'].isna(), ['all', 'unverified']].value_counts().unstack(fill_value=0)
# Out:
# unverified         evening type  intermediate type  morning type
# all
# evening type                  0                107             5
# intermediate type             0                  0            65
# morning type                  1                  4             0

# %% [markdown]
# 107 users were assigned to the evening type column when clustering all users, and are intermediate when only considering unverified users

# %%
merged_centers.apply(lambda x: pd.Series((x.idxmax(), x.idxmin()), index=['max', 'min']), axis=1).unstack(level=0).loc[Clusters.order()]
# Out:
#                      max                        min
# type                 all unverified verified    all unverified verified
# cluster
# infrequent type    21.25      21.25    12.25   6.00       6.00     5.75
# morning type        9.25       9.25     9.25   2.75       2.75     2.75
# intermediate type  18.00      18.00    11.75   4.50       4.50     5.50
# evening type       23.75      23.75    14.25  10.00      10.50     0.00

# %%
sns.lineplot(
    data=merged_centers.stack().reset_index().rename(columns={'level_1': 'cluster'}), 
    x=Columns.MIN_BINS15.value, y=0, palette=Clusters.palette(), hue='cluster', style='type')
# Out:
# <Axes: xlabel='min_bins15', ylabel='0'>

# %% [markdown]
# # Storing results

# %%
cluster_cols.to_parquet(get_cluster_col_path(config), compression='gzip')
